# %%
# %pip install dbt-databricks

# %%
# %cd /Workspace/Repos/0kirtirms@gmail.com/Inventory_Demand_Forecasting_and_Decision_Analytics/dbt

# %%
import os

os.environ["DATABRICKS_HOST"] = "https://dbc-078b0f6f-4fa7.cloud.databricks.com/editor/notebooks/2987240132382403?o=3425833841545838#command/6394752407522262"

# your SQL Warehouse or cluster SQL endpoint http path
os.environ["DATABRICKS_HTTP_PATH"] = "/sql/1.0/warehouses/fb931647cc4763bb"

# %%
# %sh
cd /Workspace/Repos/0kirtirms@gmail.com/Inventory_Demand_Forecasting_and_Decision_Analytics/dbt
dbt debug

# %%
# %sh
dbt run --select test_source
